# %% [markdown]
# ## Analitika üçün lazımlı olan bütün kitabxanaların yüklənməsi

# %% [markdown]
# ##### İstifadə olunacaq numpy, pandas, matplotlib və seaborn kitabxanalarını gətirin

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Datasetin yüklənməsi və kəşf edilməsi

# %% [markdown]
# ##### Dataseti yükləyin və ilk 20 dəyərini göstərin

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\Python\Fifa 2019\Fifa 2019.csv")
df.head(20)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# 19          19  192119        T. Courtois   26
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4   https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5   https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7   https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 9   https://cdn.sofifa.org/players/4/19/200389.png    Slovenia
# 10  https://cdn.sofifa.org/players/4/19/188545.png      Poland
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 12  https://cdn.sofifa.org/players/4/19/182493.png     Uruguay
# 13  https://cdn.sofifa.org/players/4/19/168542.png       Spain
# 14  https://cdn.sofifa.org/players/4/19/215914.png      France
# 15  https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 16  https://cdn.sofifa.org/players/4/19/202126.png     England
# 17  https://cdn.sofifa.org/players/4/19/194765.png      France
# 18  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 19  https://cdn.sofifa.org/players/4/19/192119.png     Belgium
#
#                                    Flag  Overall  Potential  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94
# 1   https://cdn.sofifa.org/flags/38.png       94         94
# 2   https://cdn.sofifa.org/flags/54.png       92         93
# 3   https://cdn.sofifa.org/flags/45.png       91         93
# 4    https://cdn.sofifa.org/flags/7.png       91         92
# 5    https://cdn.sofifa.org/flags/7.png       91         91
# 6   https://cdn.sofifa.org/flags/10.png       91         91
# 7   https://cdn.sofifa.org/flags/60.png       91         91
# 8   https://cdn.sofifa.org/flags/45.png       91         91
# 9   https://cdn.sofifa.org/flags/44.png       90         93
# 10  https://cdn.sofifa.org/flags/37.png       90         90
# 11  https://cdn.sofifa.org/flags/21.png       90         90
# 12  https://cdn.sofifa.org/flags/60.png       90         90
# 13  https://cdn.sofifa.org/flags/45.png       90         90
# 14  https://cdn.sofifa.org/flags/18.png       89         90
# 15  https://cdn.sofifa.org/flags/52.png       89         94
# 16  https://cdn.sofifa.org/flags/14.png       89         91
# 17  https://cdn.sofifa.org/flags/18.png       89         90
# 18  https://cdn.sofifa.org/flags/21.png       89         92
# 19   https://cdn.sofifa.org/flags/7.png       89         90
#
#                    Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0          FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1              Juventus  ...      95.0    28.0           31.0           23.0
# 2   Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3     Manchester United  ...      68.0    15.0           21.0           13.0
# 4       Manchester City  ...      88.0    68.0           58.0           51.0
# 5               Chelsea  ...      91.0    34.0           27.0           22.0
# 6           Real Madrid  ...      84.0    60.0           76.0           73.0
# 7          FC Barcelona  ...      85.0    62.0           45.0           38.0
# 8           Real Madrid  ...      82.0    87.0           92.0           91.0
# 9       Atlético Madrid  ...      70.0    27.0           12.0           18.0
# 10    FC Bayern München  ...      86.0    34.0           42.0           19.0
# 11          Real Madrid  ...      85.0    72.0           79.0           69.0
# 12      Atlético Madrid  ...      82.0    90.0           89.0           89.0
# 13      Manchester City  ...      93.0    59.0           53.0           29.0
# 14              Chelsea  ...      85.0    90.0           91.0           85.0
# 15             Juventus  ...      84.0    23.0           20.0           20.0
# 16    Tottenham Hotspur  ...      89.0    56.0           36.0           38.0
# 17      Atlético Madrid  ...      87.0    59.0           47.0           48.0
# 18         FC Barcelona  ...      69.0    25.0           13.0           10.0
# 19          Real Madrid  ...      66.0    20.0           18.0           16.0
#
#    GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0       6.0        11.0       15.0           14.0        8.0        €226.5M
# 1       7.0        11.0       15.0           14.0       11.0        €127.1M
# 2       9.0         9.0       15.0           15.0       11.0        €228.1M
# 3      90.0        85.0       87.0           88.0       94.0        €138.6M
# 4      15.0        13.0        5.0           10.0       13.0        €196.4M
# 5      11.0        12.0        6.0            8.0        8.0        €172.1M
# 6      13.0         9.0        7.0           14.0        9.0        €137.4M
# 7      27.0        25.0       31.0           33.0       37.0          €164M
# 8      11.0         8.0        9.0            7.0       11.0        €104.6M
# 9      86.0        92.0       78.0           88.0       89.0        €144.5M
# 10     15.0         6.0       12.0            8.0       10.0        €127.1M
# 11     10.0        11.0       13.0            7.0       10.0        €156.8M
# 12      6.0         8.0       15.0            5.0       15.0         €90.2M
# 13      6.0        15.0        7.0            6.0       12.0          €111M
# 14     15.0        12.0       10.0            7.0       10.0        €121.3M
# 15      5.0         4.0        4.0            5.0        8.0        €153.5M
# 16      8.0        10.0       11.0           14.0       11.0        €160.7M
# 17     14.0         8.0       14.0           13.0       14.0        €165.8M
# 18     87.0        85.0       88.0           85.0       90.0        €123.3M
# 19     85.0        91.0       72.0           86.0       88.0        €113.7M
#
# [20 rows x 89 columns]

# %% [markdown]
# ##### Baxin burda Birinci sutunda Unnamed deye bir sey var onu yığışdıraq

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# ##### Amma burda butun sutunlari gore bilmirik? Butun sutunlari gormek ucun ne etmeliyik?

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %% [markdown]
# ##### Bes reqemlerden ibaret olan sutunlar haqqinda melumatlari nece elde ede bilerem?

# %%
df.select_dtypes(include='number')
# Out:
#            ID  Age  Overall  Potential  Special  International Reputation  \
# 0      158023   31       94         94     2202                       5.0
# 1       20801   33       94         94     2228                       5.0
# 2      190871   26       92         93     2143                       5.0
# 3      193080   27       91         93     1471                       4.0
# 4      192985   27       91         92     2281                       4.0
# ...       ...  ...      ...        ...      ...                       ...
# 18202  238813   19       47         65     1307                       1.0
# 18203  243165   19       47         63     1098                       1.0
# 18204  241638   16       47         67     1189                       1.0
# 18205  246268   17       47         66     1228                       1.0
# 18206  246269   16       46         66     1321                       1.0
#
#        Weak Foot  Skill Moves  Jersey Number  Crossing  ...  Penalties  \
# 0            4.0          4.0           10.0      84.0  ...       75.0
# 1            4.0          5.0            7.0      84.0  ...       85.0
# 2            5.0          5.0           10.0      79.0  ...       81.0
# 3            3.0          1.0            1.0      17.0  ...       40.0
# 4            5.0          4.0            7.0      93.0  ...       79.0
# ...          ...          ...            ...       ...  ...        ...
# 18202        2.0          2.0           22.0      34.0  ...       43.0
# 18203        2.0          2.0           21.0      23.0  ...       43.0
# 18204        3.0          2.0           33.0      25.0  ...       55.0
# 18205        3.0          2.0           34.0      44.0  ...       50.0
# 18206        3.0          2.0           33.0      41.0  ...       33.0
#
#        Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0           96.0     33.0            28.0           26.0       6.0
# 1           95.0     28.0            31.0           23.0       7.0
# 2           94.0     27.0            24.0           33.0       9.0
# 3           68.0     15.0            21.0           13.0      90.0
# 4           88.0     68.0            58.0           51.0      15.0
# ...          ...      ...             ...            ...       ...
# 18202       45.0     40.0            48.0           47.0      10.0
# 18203       42.0     22.0            15.0           19.0      10.0
# 18204       41.0     32.0            13.0           11.0       6.0
# 18205       46.0     20.0            25.0           27.0      14.0
# 18206       43.0     40.0            43.0           50.0      10.0
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes
# 0            11.0       15.0           14.0         8.0
# 1            11.0       15.0           14.0        11.0
# 2             9.0       15.0           15.0        11.0
# 3            85.0       87.0           88.0        94.0
# 4            13.0        5.0           10.0        13.0
# ...           ...        ...            ...         ...
# 18202        13.0        7.0            8.0         9.0
# 18203         9.0        9.0            5.0        12.0
# 18204         5.0       10.0            6.0        13.0
# 18205         6.0       14.0            8.0         9.0
# 18206        15.0        9.0           12.0         9.0
#
# [18207 rows x 43 columns]

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# 25%                    1.000000      3.000000      2.000000       8.000000
# 50%                    1.000000      3.000000      2.000000      17.000000
# 75%                    1.000000      3.000000      3.000000      26.000000
# max                    5.000000      5.000000      5.000000      99.000000
#
#            Crossing  ...     Penalties     Composure       Marking  \
# count  18159.000000  ...  18159.000000  18159.000000  18159.000000
# mean      49.734181  ...     48.548598     58.648274     47.281623
# std       18.364524  ...     15.704053     11.436133     19.904397
# min        5.000000  ...      5.000000      3.000000      3.000000
# 25%       38.000000  ...     39.000000     51.000000     30.000000
# 50%       54.000000  ...     49.000000     60.000000     53.000000
# 75%       64.000000  ...     60.000000     67.000000     64.000000
# max       93.000000  ...     92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    18159.000000   18159.000000  18159.000000  18159.000000
# mean        47.697836      45.661435     16.616223     16.391596
# std         21.664004      21.289135     17.695349     16.906900
# min          2.000000       3.000000      1.000000      1.000000
# 25%         27.000000      24.000000      8.000000      8.000000
# 50%         55.000000      52.000000     11.000000     11.000000
# 75%         66.000000      64.000000     14.000000     14.000000
# max         93.000000      91.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  18159.000000   18159.000000  18159.000000
# mean      16.232061      16.388898     16.710887
# std       16.502864      17.034669     17.955119
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       14.000000      14.000000     14.000000
# max       91.000000      90.000000     94.000000
#
# [8 rows x 43 columns]

# %% [markdown]
# ## Preprocessing (Oyunçu dəyərinin rəqəmə çevrilməsi)

# %% [markdown]
# ##### Value sutununa baxmaq isteyirem. Sutunun ilk 10 reqemini nece gore bilerem?

# %%
deyer=df['Value']
deyer.head(10)
# Out:
# 0    €110.5M
# 1       €77M
# 2    €118.5M
# 3       €72M
# 4      €102M
# 5       €93M
# 6       €67M
# 7       €80M
# 8       €51M
# 9       €68M
# Name: Value, dtype: object

# %% [markdown]
# ##### Burda Euro isaresini cixaririq, M herfini 1000000-la, K herfini ise 1000-le evezleyirik

# %%
deyer1=deyer.str.replace('€','').str.replace('M','1000000').str.replace('K','1000').str.strip()

# %%
def func(x):
    if len(x)>7:
       return (pd.to_numeric(x[0:len(x)-7], errors='coerce'))*1000000
    else:
        return int(x[0:2])*1000

# %%
value=deyer1.apply(func)

# %% [markdown]
# ##### İndi isə sütunu iki hissəyə böləcək kod yazın və bu iki sütunu bir birinə vuraraq real "Value" sütununu əldə edin (float tipində)

# %%
df['Value']=value

# %% [markdown]
# ##### Menim sutunumda null deyerler ola biler. Men isteyirem ki bunu 0 ile evez edim

# %%
df['Value'].fillna(value=0)
# Out:
# 0        110500000.0
# 1         77000000.0
# 2        118500000.0
# 3         72000000.0
# 4        102000000.0
#             ...
# 18202        60000.0
# 18203        60000.0
# 18204        60000.0
# 18205        60000.0
# 18206        60000.0
# Name: Value, Length: 18207, dtype: float64

# %% [markdown]
# ## Visualization and Analysis

# %% [markdown]
# #####  Oyunçuların Pozisiya paylanması (Categorical)

# %% [markdown]
# Bir fiqur (10,10) yaradın Bu fiqur daxilində hansı pozisiyadan neçə nəfər uyğun chart vasitəsilə göstərin ("Position" sütunu)

# %%
plt.figure(figsize=(10,10)) 
plt.ylabel('Count')
position=df['Position'].value_counts().reset_index()
sns.barplot(x='Position',y='count',data=position)
# Out:
# <Axes: xlabel='Position', ylabel='Count'>

# %% [markdown]
# #### Oyunçuların yaş paylanması (Numeric)

# %% [markdown]
# Bir fiqur (10,10) yaradın Bu fiqur daxilində hansı yaş sütununu uyğun chart vasitəsilə göstərin ("Age" sütunu)

# %% [markdown]
# Bir də bunu kde plot vasitəsilə verin

# %%
plt.figure(figsize=(10,10)) 
yas=df['Age'].value_counts().reset_index()
sns.barplot(x='Age',y='count',data=yas)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.kdeplot(x=df['Age'],fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ###  Oyunçuların istifadə etdiyi ayağının qiymətə təsiri

# %% [markdown]
# ##### Birinci oyuncularin hansi ayagini istifade etdiyini oyrenek. Yeni hansi ayagindan (sol ve ya sag) istifade eden nece neferdi?

# %%
print('Sağ ayağ istifadə edənlərin sayı: ',df[df['Preferred Foot']=='Right']['ID'].count())
# Out:
# Sağ ayağ istifadə edənlərin sayı:  13948

# %%
print('Sol ayağ istifadə edənlərin sayı:' ,df[df['Preferred Foot']=='Left']['ID'].count())
# Out:
# Sol ayağ istifadə edənlərin sayı: 4211

# %% [markdown]
# ##### Bir de bunu qrafik kimi gorek. Kateqoriya ucun hansi plotdan istifade etmeliyem?

# %%
ayaq=df['Preferred Foot'].value_counts().reset_index()
plt.bar(ayaq['Preferred Foot'],ayaq['count'])
plt.xlabel('Preferred Foot')  # x oxu adı
plt.ylabel('Number of Players')  # y oxu adı
plt.title('Distribution of Preferred Foot')  # qrafik başlığı
plt.show()

# %% [markdown]
# ##### Bunu bir də pie chart kimi görmək istəyirəm ki, paylar necə bölünür?

# %%
plt.pie(df.groupby('Preferred Foot')['ID'].sum(),labels=df.groupby('Preferred Foot')['ID'].sum().index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22323857b60>,
#   <matplotlib.patches.Wedge at 0x22325c55090>],
#  [Text(0.8206058842483018, 0.7325339464741977, 'Left'),
#   Text(-0.8206056455584015, -0.7325342138614954, 'Right')],
#  [Text(0.4476032095899828, 0.3995639708041078, '23.2%'),
#   Text(-0.4476030793954917, -0.3995641166517247, '76.8%')])

# %% [markdown]
# ##### Qruplaşdırma funksiyalarından istifadə edərək istifadə edilən ayağa görə ortalama qiyməti tapın

# %%
df.groupby('Preferred Foot')['Value'].mean().round()
# Out:
# Preferred Foot
# Left     2346022.0
# Right    2132680.0
# Name: Value, dtype: float64

# %% [markdown]
# ##### İndi bunu Bar chart kimi görmək istəyirəm

# %%
plt.bar(df.groupby('Preferred Foot')['Value'].mean().round().index,df.groupby('Preferred Foot')['Value'].mean().round())
plt.ticklabel_format(style='plain', axis='y')

# %%
plt.figure(figsize=(15,10))
#oyuncularin yaş paylanması
plt.subplot(2,2,1)
yas=df['Age'].value_counts().reset_index()
sns.barplot(x='Age',y='count',data=yas)
plt.subplot(2,2,2)
sns.kdeplot(x=df['Age'],fill=True)
# hansi ayagindan (sol ve ya sag) istifade eden nece neferdi?
plt.subplot(2,2,3)
plt.pie(df.groupby('Preferred Foot')['ID'].sum(),labels=df.groupby('Preferred Foot')['ID'].sum().index,autopct='%1.1f%%')
plt.subplot(2,2,4)
#istifadə edilən ayağa görə ortalama qiymət
plt.bar(df.groupby('Preferred Foot')['Value'].mean().round().index,df.groupby('Preferred Foot')['Value'].mean().round())
plt.ticklabel_format(style='plain', axis='y')
plt.ylabel('Average value')
#plt.show()
# Out:
# Text(0, 0.5, 'Average value')

# %% [markdown]
# ### İstifadə olunan ayağın və pozisiyanın qiymətə təsiri

# %% [markdown]
# Birinci sag ve sol ayagin pozisiyalara gore saylarini tapmaq isteyirem. Bunun ucun countplotdan istifade edecem

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Position',data=df,hue='Preferred Foot')
# Out:
# <Axes: xlabel='Position', ylabel='count'>

# %% [markdown]
# Indi ise isin icine qiymeti de qatmaliyam. Amma burda y axisi de vermeliyem. Hansi plotdan istifade etmeliyem?

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Position',y='Value',data=df,ci=False,hue='Preferred Foot')
plt.ticklabel_format(style='plain', axis='y')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10612\534931216.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='Position',y='Value',data=df,ci=False,hue='Preferred Foot')

# %% [markdown]
# ### Beynəlxalq Reputasiya və Oyunçu Potensialı arasındakı əlaqə

# %%
df['International Reputation'].unique()
# Out:
# array([ 5.,  4.,  3.,  2.,  1., nan])

# %% [markdown]
# ##### Bu analizi aparmaq ucun men swarm plota yaxin ve daha suretli bir plot novunden istifade edecem

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['International Reputation'], df['Potential'], alpha=0.6, s=50)
plt.xlabel('International Reputation')
plt.ylabel('Potential')
plt.title('Scatter Plot')
plt.grid(True)
plt.show() 
#'bu deyerler arasinda elaqe yoxdur'

# %% [markdown]
# ### Beynəlxalq Reputasiya və Oyunçu Potensialı - İstifadə olunan ayaq arasındakı əlaqə

# %% [markdown]
# Bunun ucun strip plotdan istifade edin ve hue elave edin

# %%
sns.stripplot(x='International Reputation', y='Potential',data=df,hue='Preferred Foot')
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %% [markdown]
# Buna bir dene de boxplotla baxmağınızı istəyirəm

# %%
sns.boxplot(x='International Reputation', y='Potential',data=df,hue='Preferred Foot')
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %% [markdown]
# ### Oyunçuların Potensialları və Gücləri arasında əlaqə

# %% [markdown]
# Buna birinci seabornda olan lineplotla baxmaq isteyirem

# %%
sns.lineplot(x='Potential',data=df,y='Overall')
# Out:
# <Axes: xlabel='Potential', ylabel='Overall'>

# %% [markdown]
# ##### Oyunçuların Potensialları və Gücləri-İstifadə olunan ayaq arasında

# %%
sns.lineplot(x='Potential',data=df,y='Overall',hue='Preferred Foot')
plt.show()

# %% [markdown]
# ## Dashboard

# %% [markdown]
# Bir fiqur yaradın (15,15). Daha sonra 4 ədəd subplot yaradın və yuxarıda qurduğunuz 4 plotu bu dashboard-a yerləşdirin

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.stripplot(x='International Reputation', y='Potential',data=df,hue='Preferred Foot')
plt.subplot(2,2,2)
sns.boxplot(x='International Reputation', y='Potential',data=df,hue='Preferred Foot')
plt.subplot(2,2,3)
sns.lineplot(x='Potential',data=df,y='Overall')
plt.subplot(2,2,4)
sns.lineplot(x='Potential',data=df,y='Overall',hue='Preferred Foot')
# Out:
# <Axes: xlabel='Potential', ylabel='Overall'>
